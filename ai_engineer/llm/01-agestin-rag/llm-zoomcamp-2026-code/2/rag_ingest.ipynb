# %%
from ingest import load_faq_data, build_index

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
from rag_helper import search
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from rag_helper import search
#
# ImportError: cannot import name 'search' from 'rag_helper' (c:\Users\mulwo\Desktop\projects\note-app\ai_engineer\llm\01-agestin-rag\llm-zoomcamp-2026-code\rag_helper.py)

# %%
search('docker')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 search('docker')
#
# NameError: name 'search' is not defined
