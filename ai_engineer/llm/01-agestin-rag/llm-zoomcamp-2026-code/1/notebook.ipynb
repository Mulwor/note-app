# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
def llm(prompt):
    response = openai_client.responses.create(
        model='gpt-5.4-mini',
        input=prompt
    )
    return response.output_text

# %%
question = 'I just discovered the course. Can I join now?'
answer = llm(question)
print(answer)

'''
Выдаст ответ, в котором говорит, что он не знает что за курс и просит больше контекста добавить 

Yes—probably, if enrollment is still open.

If you want, send me:
- the course name
- the platform or school
- whether it’s live, self-paced, or cohort-based

and I can help you figure out:
- if late entry is allowed
- what you may have missed
- the best way to ask the instructor or support team

If you’re asking generally, the quickest thing to check is the course page for:
- “enroll now”
- “start date”
- “auditing”
- “late registration”

If you want, I can also help you draft a short message asking to join.
'''
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 question = 'I just discovered the course. Can I join now?'
# ----> 2 answer = llm(question)
#       3 print(answer)
#       4
#       5 '''
#
# Cell In[3], line 2, in llm(prompt)
#       1 def llm(prompt):
# ----> 2     response = openai_client.responses.create(
#       3         model='gpt-5.4-mini',
#       4         input=prompt
#       5     )
#
# ...

# %%
# Ну мы и добавляем немного больше контекста

context = '''
I just discovered the course. Can I still join?
Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.

edit on GitHub
#Course: I have registered for the LLM Zoomcamp. When can I expect to receive the confirmation email?
You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.

edit on GitHub
#What is the video/zoom link to the stream for the “Office Hours” or live/workshop sessions?
The zoom link is only published to instructors/presenters/TAs.

Students participate via YouTube Live and submit questions to Slido (link is pinned in the chat when live). The video URL should be posted in the announcements channel on Telegram &amp; Slack before it begins. You can also watch live on the DataTalksClub YouTube Channel.

Don’t post questions in chat as they may be missed if the room is very active.

edit on GitHub
#Cloud alternatives with GPU
Check the quota and reset cycle carefully. Is the free hours limit per month or per week? Usually, if you change the configuration, the free hours quota might also be adjusted, or it might be billed separately.

Potential options include:

Google Colab
Kaggle
Databricks (possibly)
Consider using GPTs to discover more options. Be aware that some platforms might have restrictions on what you can and cannot install, so ensure to read what is included in the free vs paid tier.
'''

# %%
# Теперь мы создаем промпт, где задача отвечать на вопросы студентов из предоставленного контекста
prompt = f'''

Your task is to answer questions from the course participants
based on the provided context.

Use the context to find relevant information and provide accurate
answers. If the answer is not found in the context,
respond with "I don't know."

Question:
{question}

Context:
{context}
'''

# %%
question = 'I just discovered the course. Can I join now?'
answer = llm(prompt)
print(answer)

# Yes, you can still join. If you want to receive a certificate, you need to submit your project while submissions are still open.
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 question = 'I just discovered the course. Can I join now?'
# ----> 2 answer = llm(prompt)
#       3 print(answer)
#       4
#       5 # Yes, you can still join. If you want to receive a certificate, you need to submit your project while submissions are still open.
#
# Cell In[3], line 2, in llm(prompt)
#       1 def llm(prompt):
# ----> 2     response = openai_client.responses.create(
#       3         model='gpt-5.4-mini',
#       4         input=prompt
#       5     )
#
# ...

# %%
def rag(question):
    # Поиск
    search_results = search(question)
    # Создания промпта
    user_prompt = build_prompt(question, search_results)
    # Отправка его
    return llm(user_prompt)

# %%
import requests

# Получение всех курсов
docs_url = "https://datatalks.club/faq/json/courses.json"
response = requests.get(docs_url)
courses_raw = response.json()

'''
[
  {
    "course": "machine-learning-zoomcamp",
    "course_name": "ML Zoomcamp",
    "path": "/json/machine-learning-zoomcamp.json",
    "questions_count": 471
  },
  {
    "course": "stock-markets-analytics-zoomcamp",
    "course_name": "Stock Markets Analytics Zoomcamp",
    "path": "/json/stock-markets-analytics-zoomcamp.json",
    "questions_count": 93
  },
  {
    "course": "ai-dev-tools-zoomcamp",
    "course_name": "AI Dev Tools Zoomcamp",
    "path": "/json/ai-dev-tools-zoomcamp.json",
    "questions_count": 41
  },
  {
    "course": "llm-zoomcamp",
    "course_name": "LLM Zoomcamp",
    "path": "/json/llm-zoomcamp.json",
    "questions_count": 144
  },
  {
    "course": "mlops-zoomcamp",
    "course_name": "MLOps Zoomcamp",
    "path": "/json/mlops-zoomcamp.json",
    "questions_count": 253
  },
  {
    "course": "data-engineering-zoomcamp",
    "course_name": "Data Engineering Zoomcamp",
    "path": "/json/data-engineering-zoomcamp.json",
    "questions_count": 404
  }
]
'''
# Out:
# '\n[\n  {\n    "course": "machine-learning-zoomcamp",\n    "course_name": "ML Zoomcamp",\n    "path": "/json/machine-learning-zoomcamp.json",\n    "questions_count": 471\n  },\n  {\n    "course": "stock-markets-analytics-zoomcamp",\n    "course_name": "Stock Markets Analytics Zoomcamp",\n    "path": "/json/stock-markets-analytics-zoomcamp.json",\n    "questions_count": 93\n  },\n  {\n    "course": "ai-dev-tools-zoomcamp",\n    "course_name": "AI Dev Tools Zoomcamp",\n    "path": "/json/ai-dev-tools-zoomcamp.json",\n    "questions_count": 41\n  },\n  {\n    "course": "llm-zoomcamp",\n    "course_name": "LLM Zoomcamp",\n    "path": "/json/llm-zoomcamp.json",\n    "questions_count": 144\n  },\n  {\n    "course": "mlops-zoomcamp",\n    "course_name": "MLOps Zoomcamp",\n    "path": "/json/mlops-zoomcamp.json",\n    "questions_count": 253\n  },\n  {\n    "course": "data-engineering-zoomcamp",\n    "course_name": "Data Engineering Zoomcamp",\n    "path": "/json/data-engineering-zoomcamp.jso
# ...

# %%
documents = []
url_prefix = "https://datatalks.club/faq"

for course in courses_raw:
    course_url = f"""{url_prefix}{course["path"]}"""

    # Отправляем запрос на получения данных
    course_response = requests.get(course_url)
    # Если произойдет сбой необходимо создать ошибку
    course_response.raise_for_status()
    # затем получаем json и помещаем в один список
    course_data = course_response.json()

    documents.extend(course_data)

len(documents)
# Out:
# 1406

# %%
documents[1000]

'''
 'id': 'b6c7eb17d8',
 'course': 'mlops-zoomcamp',
 'section': 'Capstone Project',
 'question': 'How is my capstone project going to be evaluated?
 'answer': 'Of course'
'''
# Out:
# "\n 'id': 'b6c7eb17d8',\n 'course': 'mlops-zoomcamp',\n 'section': 'Capstone Project',\n 'question': 'How is my capstone project going to be evaluated?\n 'answer': 'Of course'\n"

# %%
from minsearch import Index

index = Index(
   # Все поля которые можно использовать в качестве поиска (должно быть точное совпадение)
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"]
)

index.fit(documents)

# %%
search_result = index.search(
  question,
  filter_dict = {'course': 'llm-zoomcamp'},
  num_results = 5 
)

# %%
def search(question, course ='llm-zoomcamp'): 
  # Указываем важность поля, по умолчанию у всех 1
  boost_dict = {'question': 2.0, 'section': 0.5 }
  filter_dict = {'course': course}

  return index.search(
    question,
    boost_dict = boost_dict,
    filter_dict = filter_dict,
    num_results = 5 
)

# %%
search_results = search(question)
print(search_results)
# Out:
# [{'id': '74eb249bbf', 'course': 'llm-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'I just discovered the course. Can I still join?', 'answer': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.'}, {'id': '977bf7786c', 'course': 'llm-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'Course: I have registered for the LLM Zoomcamp. When can I expect to receive the confirmation email?', 'answer': "You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date."}, {'id': '5cc511f85b', 'course': 'llm-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'Does the course certificate show the number of course hours?', 'answer': 'No. The certificate does not state a total number of 
# ...

# %%
# Build prompt -  — это мост, который превращает сырые данные (результаты 
# поиска) в понятный для LLM запрос. Без неё LLM либо не увидит ваши документы, 
# либо не поймёт, как их использовать.

# Вот 4 ключевые причины, зачем их создавать:

# 1. Структурирование информации (результат поиск - это список словарей 
# с полями (раздел, вопрос, ответ). LLM работает с текстом, а не 
# со словарями. Функция build_context превращает этот список в одну 
# читаемую строку с чёткими блоками (раздел → Q → A). Так LLM легче
# усваивает данные.

# 2. Добавление инструкций В инструкциях (INSTRUCTIONS) вы говорите LLM: 
# «Отвечай только по контексту, если не знаешь — скажи "I don't know"». 
# Без этих инструкций модель может начать фантазировать (галлюцинировать) 
# или отвечать из своей внутренней памяти, игнорируя ваши документы.

# 3. Разделение фиксированной и изменяемой части 
# - Инструкции (системная подсказка) — постоянны для всех вопросов. 
# - Подсказка пользователя — каждый раз новая (вопрос + контекст). Разде-
# ление позволяет не дублировать инструкции в каждом запросе и легко 
# собирать конечный промпт.

# 4. Контроль формата ответа - В шаблоне USER_PROMPT_TEMPLATE вы 
# явно указываете: сначала вопрос, потом контекст. Это помогает 
# LLM понять, что именно искать, и выдавать ответ в ожидаемом виде.

# %%
# Программа LLM не видит наши документы, если мы их не передадим. Поэтому 
# нам нужно создать запрос, который будет включать вопрос пользователя и 
# результаты поиска. При создании систем искусственного интеллекта мы 
# обычно разделяем задачу на две части:

# - Инструкции (также называемые системной подсказкой): они указывают LLM, 
# как себя вести. Они никогда не меняются, поэтому одинаковы для каждого 
# запроса.
# - Подсказка пользователю: она меняется с каждым запросом. Она содержит 
# сам вопрос и полученный контекст.

# Мы разделили их, потому что инструкции фиксированы, а подсказки для 
# пользователя — нет. Разделение позволяет легко повторно использовать 
# фиксированную часть и легко создавать новую, изменяемую.

# %%
# В инструкциях указывается роль магистра права и порядок ответа:

INSTRUCTION = '''
Your task is to answer questions from the course participants
based on the provided context.

Use the context to find relevant information and provide accurate
answers. If the answer is not found in the context,
respond with "I don't know."
'''

# Именно это позволяет подтвердить ответ данными и уменьшить 
# количество галлюцинаци

# %%
# Создание промпта
USER_PROMPT_TEMPLATE = f'''
Question:
{question}

Context:
{context}
'''

# %%
# Это context отформатированная строка со всеми результатами поиска:
# Каждый документ становится блоком, содержащим раздел, вопрос и ответ. 
# Такой формат облегчает чтение для LLM. Мы преобразовали список 
# словарей в одну строку. Это небольшой этап предварительной обработки перед отправкой данных в LLM.
def build_context(search_results):
  lines = []

  for doc in search_results:
      lines.append(doc["section"])
      lines.append("Q: " + doc["question"])
      lines.append("A: " + doc["answer"])
      lines.append("")

  return "\n".join(lines).strip()

# %%
# Теперь объединим prompt с контекстом в подсказку для пользователя:
def build_prompt(question, search_results):
  context = build_context(search_results)
  prompt = USER_PROMPT_TEMPLATE.format(
    question = question,
    context = context
  )
  return prompt.strip()

# %%
prompt = build_prompt(question, search_results)

print(prompt)
# Out:
# Question:
# I just discovered the course. Can I join now?
#
# Context:
#
# I just discovered the course. Can I still join?
# Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.
#
# edit on GitHub
# #Course: I have registered for the LLM Zoomcamp. When can I expect to receive the confirmation email?
# You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.
#
# edit on GitHub
# #What is the video/zoom link to the stream for the “Office Hours” or live/workshop sessions?
# The zoom link is only published to instructors/presenters/TAs.
#
# ...

# %%
# Build prompt -  — это мост, который превращает сырые данные (результаты 
# поиска) в понятный для LLM запрос. Без неё LLM либо не увидит ваши документы, 
# либо не поймёт, как их использовать.

# Вот 4 ключевые причины, зачем их создавать:

# 1. Структурирование информации (результат поиск - это список словарей 
# с полями (раздел, вопрос, ответ). LLM работает с текстом, а не со словарями
# Функция build_context превращает этот список в одну читаемую строку с
# чёткими блоками (раздел → Q → A). Так LLM легче усваивает данные.

# 2. Добавление инструкций В инструкциях (INSTRUCTIONS) вы говорите LLM: 
# «Отвечай только по контексту, если не знаешь — скажи "I don't know"». 
# Без этих инструкций модель может начать фантазировать (галлюцинировать) 
# или отвечать из своей внутренней памяти, игнорируя ваши документы.

# 3. Разделение фиксированной и изменяемой части 
# - Инструкции (системная подсказка) — постоянны для всех вопросов. 
# - Подсказка пользователя — каждый раз новая (вопрос + контекст). Разделение
# позволяет не дублировать инструкции в каждом запросе и легко собирать
# конечный промпт.

# 4. Контроль формата ответа - В шаблоне USER_PROMPT_TEMPLATE вы 
# явно указываете: сначала вопрос, потом контекст. Это помогает 
# LLM понять, что именно искать, и выдавать ответ в ожидаемом виде.

# Пример из вашего файла: Если бы вы просто отправили в LLM голый 
# вопрос «Могу ли я присоединиться к курсу?», она бы ответила из 
# своих общих знаний. А через подсказку вы вставляете реальные 
# FAQ курса, и LLM даёт точный ответ: «Да, но если хотите сертификат,
# сдайте проект до дедлайна».

# Итог: build_prompt — это не просто форматирование, это инструмент 
# управления поведением LLM. Без него ваша RAG-система не будет 
# работать надёжно.

# %%
# Lesson:
# ? RAG Pipeline

response = openai_client.responses.create(
  model = 'gpt-5.4-mini',
  input = prompt
)

response.output_text 
# 'Yes — you can still join now and start learning/submitting homework 
# while the form is open.\n\nIf you want a certificate, make sure to 
# submit your project before submissions close.'

response.output[0].content[0].text
# 'Yes — you can still join now and start learning/submitting homework 
# while the form is open.\n\nIf you want a certificate, make sure to 
# submit your project before submissions close.'

response.usage
# ResponseUsage(input_tokens=334, input_tokens_details=InputTokensDetails
# (cached_tokens=0), output_tokens=39, output_tokens_details=
# OutputTokensDetails(reasoning_tokens=0), total_tokens=373)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[58], line 4
#       1 # Lesson:
#       2 # ? RAG Pipeline
#       3
# ----> 4 response = openai_client.responses.create(
#       5   model = 'gpt-5.4-mini',
#       6   input = prompt
#       7 )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openai\resources\responses\responses.py:1023, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     982 def create(
# ...

# %%
# Функция для расчета стоимости токенов
input_price = 0.75 / 1_000_000
output_price = 4.50 / 1_000_000

inputToken = response.usage.input_tokens,
outputToken = response.usage.output_tokens

cost = (inputToken * input_price + outputToken * output_price)
cost

# 0.00042600000000000005
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 6
#       2 input_price = 0.75 / 1_000_000
#       3 output_price = 4.50 / 1_000_000
#       4
#       5 cost = (
# ----> 6   response.usage.input_tokens * input_price +
#       7   response.usage.output_tokens * output_price
#       8 )
#       9
#
# AttributeError: 'Response' object has no attribute 'usage'

# %%
# В начале чат гпт под капотом определяет системые требования, то
# есть откуда человек, из какой локации и прочее, затем уже когда 
# вы написали сообщение - он собрал всю необходимо информацию и выда-
# ет вам. Условно как погода? - Если вы в берлине находитесь, то скажет 
# облачно

def llm(instructions, user_prompt, model='gpt-5.4-mini'):
    message_history = [
        {'role': 'developer', 'content': instructions},
        {'role': 'user', 'content': user_prompt}
    ]

    response = openai_client.responses.create(
        model = model,
        input = message_history
    )

    return response.output_text

# %%
def rag(query, model="gpt-5.4-mini"):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(INSTRUCTION, prompt, model=model)
    return answer

# %%
answer = rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 answer = rag("I just discovered the course. Can I join now?")
#       2 print(answer)
#
# Cell In[25], line 7, in rag(question)
#       3     search_results = search(question)
#       4     # Создания промпта
#       5     user_prompt = build_prompt(question, search_results)
#       6     # Отправка его
# ----> 7     return llm(user_prompt)
#
# Cell In[11], line 2, in llm(prompt)
#       1 def llm(prompt):
# ----> 2     response = openai_client.responses.create(
#       3         model='gpt-5.4-mini',
#       4         input=prompt
#       5     )
#
# ...

# %%
rag("How do I get a certificate?")

# %%
# ? -- Lesson: RAG Helper --

# В предыдущих уроках мы поэтапно выстраивали RAG-процесс: поиск, 
# затем подсказка, затем вызов LLM. Конвейер работает, но каждый раз,
# когда мы хотим его использовать, нам приходится повторять один 
# и тот же код.

# Этот код будет использоваться на протяжении всего курса, поэтому 
# давайте разделим его на два многоразовых файла:

# - ingest.py — загрузка данных и построение поискового индекса.
# - rag_helper.py — логика RAG (поиск, подсказка, LLM)

# Затем в блокнотах мы просто импортируем файлы из этих файлов и используем их.
