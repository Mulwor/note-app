# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag("I just discovered the course, can i still join?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 assistant.rag("I just discovered the course, can i still join?")
#
# File ~\Desktop\projects\note-app\ai_engineer\llm\01-agestin-rag\llm-zoomcamp-2026-code\2\rag_helper.py:77, in RAGBase.rag(self, query)
#      76 def rag(self, query):
# ---> 77   search_results = self.search(query)
#      78   prompt = self.build_prompt(query, search_results)
#      79   answer = self.llm(prompt)
#
# File ~\Desktop\projects\note-app\ai_engineer\llm\01-agestin-rag\llm-zoomcamp-2026-code\2\rag_helper.py:38, in RAGBase.search(self, query, num_results)
#      35 boost_dict = {'question': 2.0, 'section': 0.5 }
#      36 filter_dict = {'course': self.course}
# ---> 38 return self.index.search(
#      39   query,
#      40   boost_dict = boost_dict,
#      41   filter_dict = filter_dict,
#      42   num_results = num_results,
#      43 )
#
# AttributeError: 'tuple' object has no attribute 'search'
